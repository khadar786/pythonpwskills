# %%
#Data Structure and Algorithm
#What - Why - How
#Structing Data ,Arraging Data
#Data ] 1.storage 2.computation - Trivial job
#Human civilization ----------------->
#Every company ->Data Hungry Huge amount of data (1.storage 2.computation)
#DS ->what / why ?
#Data -Stored Computed
#is every data important to collect?

#irctc
#click time,features,interation,transaction time

#Algorithm
#Problem - logical step to solve the problem
#House ---------------->Airport
#How do you we choose the best algorithm
#->Time complexity
#P A1 ->t1 seconds,A2 ->t2 seconds t1<t2 can i say A1 is better than A2 -{Correct Answer :Depends}
#Time taken by an algorithm :
#1.Logic
#2.PL ->scripting Python solwer than C++,Java
#3.OS

#Compare algorithms
#Based on execustion time
#Algo is good in python,c++,java

#Time Complexity ->choose algorithm ->independent of OS/Processor/Programming Language

#what is time complexity
#How the number of operations are propotional to input size

#def printNum(n):
# for i in range(n):
#    print("hello world")
#TC = O(n)

# def printName(n):
#     print("Hello world")
#n=0 | 1
#n=10 | 1
#n=13 | 1
#No of operation is independent of n
#TC =O(1)


# def printName(n):
#     for i in range(n):
#         for j in range(n):
#             print("Hello world")
# n=1 | 1
# n=2 | 4
# n=3 | 9
# n=4 | 16
#No of operation proposional n^2
#TC=O(n^2)

# def printName(n):
#     i=1
#     while i<n:
#         i=i*2
#         print("hello world")
##No operation <input size
#1 -> i=1 =2^0 =2^1-1
#2 -> i=2 =2^1 =2^2-1
#3 -> i=4 =2^2 =2^3-1
#4 -> i=8 =2^3 =2^4-1
#k times i = 2^k-1 ---------------------(k+1)th ->i=2^k
#i>=n
#2^k ~n
#no of time loop rand - no of operations
#+.log 2^2 = log n
#k~ logn
#Tc =O(log n)

# %%
# def printName(n):
#     for i in range(n): TC =O(n)
#         j=1
#         while j<n: TC =O(log n)
#             j=j*2
#             print("Hello")

#TC = O(n log n)

# %%
# loop -> T1
#     loop -> T2
#         loop ->T3
# TC = T1 + T2 + T3

# ------------------
# loop1 -> T1
# loop2 -> T2
# loop3 -> T3

# TC = Max(T1,T2,T3)

# %%
# def printName(n):
#     for i in range(n): TC =N
#         for j in range(n): TC=1
#             print('Hello')
#             break
# TC = n*1
#    =O(n)

# %%
# def printName(n):
#     i=s=1
#     while s<n:
#         i+=1
#         s+=i
#         print("Hello")
# No of operations 2^k~n
# n=10
# i=1,s=1
# i=2 s=1+2
# i=3 s=1+2+3
# i=4 s=1+2+3+4
# i=5 s=1+2+3+4+5
# sk=1+2+3+4+5+.....ktimes
# sk=k(k+1)/2
# k+1=(k+1)(k+1)/2
# k^2+3k+4 propotional n 
# No of times while tn loop times k
# TC =O(sqrt n)

# %%
# TC = Best case,Average case,Worst case
