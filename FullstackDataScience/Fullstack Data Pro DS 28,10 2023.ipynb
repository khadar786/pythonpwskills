# %%
#https://github.com/priya6971/FAANG-DSA-Live-Batch
#https://github.com/priya6971/Full-Stack-Data-Science-Pro-Batch
#https://drive.google.com/drive/folders/1Ws9Avx9U-N4qLJToT15_EE0F4lC7uUyc

#Data Structure & Algorithms (Problem Solvings)
#efficiency store the data
#Linear
# Arrays
# Linked List
# Stack & Queue
# Hash (Dictionary)

#Non - Linear
# Tree
# Graphs



#Algorithm (Logical building)
#Set of instructions to solve a specific problem

#Divide & Conquer algorithms
#Greedy algorithms
#Dynamic Programming

#Leetcode

#Independent of any prgramming language

#Data Science (Projects)
#|
#DSA

#Coding - Technical - Interview

#Time Complexity
#->less time completed
#amount of time to execute a program

# sum of n natural numbers
# n=6

#approach 1
# sum=0
# for i=1 to 6
# sum+=1
# return sum
# O(n) - approximation

#approach 2
#sum=n(n+1)/2
#O(1) - constant

#Space Complexity
#->Less space complexity
#extra time execute a program

#Perfection
#Ideal situation -> Time complexity + Space complexity

#Trade off

#situation 1
#time more + space less

#situation 2
#time less +space
#using

#Module 1
#Analysis Module
#optimized code
#leser time & leser space
#Great Developer

#To differnt analysis
#1.Apriori analysis
#approximations & logic
#not dependent on hardware
#O(n)

# n=3000 / 3 lac
# even,odd

#2.Apostiary analysis
#Research
#exact results & type of hardware
#super computers

# %%
#Apriori analysis
#Time & space complexity

# %%
#Time complexity - order of magnitue of the statement (times any statement is execute)
#example 1
# y=7
# z=8
# x=y+z ->O(1)
# constant time complexity
# O is notation (Worst case)

# #example 2
# for i in range(n):
#     x=y+z
# O(n) ->time complexity

# #example 3
# x=y+z
# for i in range(n):
#     x=y+z
    
# for i in range(n)
#     for y in range(n):
#         x=y+z
# O(n2)


# 1.Loop (for,while) ->time complexity
# 2.Bigger loop ->Time complexity
# #n+n2+n3 =O(n3)
# #.No loop -> constant time complexity 
# O(1)

#conditional statement (if elif else)
#O(1)

#example 4 - while
# i=n
# while(i>1):
#     i=i-1
# O(n)
#n ----------------(n-1) times

#example 5
# i=n
# while(i>=1)
#     i=i-2
#     i=i=3-2
# O(n)

# i=0
# i=8,i=6,i=4,i=2>=1
# i=6,i=4,i=2,i=2

#25/5=n/5

#example 6
# i=n
# while(i>2):
#     i=i power of 1/2

# n=16
# i=16,i=16 power 1/2,2 power 2,
# i=4,i=4 power 1/2,power 2
# k times
# n power 1/2k=2
#log power a base 2=b log pwer n base a

# %%
# external data structure
# arr-dictionary   to store the results - merge sort
# O(n)

# Binary search -O(log n)

# %%
#complexity classes
#increasing order
# 1.constant complexity -> O(1)
# 2.logarithmic complexity(Binary search) ->O(log power n base 2)
# 3.Liner complexity - O(n)
# 4.Quadratic complexity -> O(n power 2)
# 5.Cubic complexity -> O(n power 3)
# 6.Polynomial complexity ->O(n power c) c>0

# #Recursion,Dynamic programming
# 7.exponential complexity ->O(2 power n)
# O(c power n) c>1

# %%
# numbers
# number system
# logirthm
# ap& gp series (formula)
# calculas
# probability & statics
# matrix computation

# %%
# Asymptotic Notations
# Best case - Omega
# Average case - Theta 
# worst case - n is very hig Big O =
